# %% [markdown]
# 1.3: Generalization

# %% [markdown]
# 1.3.1: Can network fit random labels?

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from torch.autograd import Variable

# %%
torch.manual_seed(1)

# MNIST dataset 
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transforms.Compose([transforms.ToTensor(),]),
                                           download=True,)
                                          
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, transform=transforms.Compose([transforms.ToTensor(),]))
print("train_dataset size:", len(train_dataset),"\ntest_dataset size:", len(test_dataset))


# Label Randomizer

randomLabel = torch.tensor(np.random.randint(0, 10, (len(train_dataset)),))
train_dataset.targets = randomLabel

# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=100, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=100, shuffle=False)
                                          
                                          

examples = iter(train_loader)
example_data, example_targets = next(examples)

class RMNIST(nn.Module):
    def __init__(self):
        super(RMNIST, self).__init__()
        
        self.fc1 = nn.Linear(784, 500)
        self.fc2 = nn.Linear(500, 10)
        

    def forward(self, x):

        # flatten as one dimension
        x = x.view(x.size()[0], -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

def train(model, optimizer, epoch, train_loader, interval):
    model.train()
    loss_fn = torch.nn.CrossEntropyLoss()
    n_correct = 0
    n_samples = 0
    

    for i, (data, target) in enumerate(train_loader):
         
        data, target = Variable(data), Variable(target)
        
        optimizer.zero_grad()

        # Forward propagation
        prediction = model(data)
        loss = loss_fn(prediction, target)
        #lossSum += loss.detach().numpy()
        
        #Backward prop
        loss.backward()
        
        optimizer.step()

        _, predicted = torch.max(prediction.data, 1)
        n_samples += target.size(0)
        n_correct += (predicted == target).sum().item()
        acc = 100.0 * n_correct / n_samples
        
        if i % interval == 0:
            print (f'Train Log:Epoch: {epoch}, Step [{i+1}/{len(train_loader.dataset)}], TrainLoss: {loss.item():.4f}')
    return loss.data, round(acc,2)

def test(model, epoch, test_loader):
    test_load = test_loader
    model.eval()
    n_correct = 0
    n_samples = 0
    testLoss = 0
    count = 0
    
    with torch.no_grad():
        for images, labels in test_load:
            images, labels = Variable(images),Variable(labels)
    
            prediction = model(images)
            testLoss += loss_func(prediction,labels).item()
            # max returns (value ,index)
            _,predicted = torch.max(prediction.data, 1)
            n_samples += labels.size(0)
            count += 1
            n_correct += (predicted == labels).sum().item()
    
        Test_loss = testLoss/count
        netTest_acc1 = 100.0 * n_correct / n_samples
        print(f'Accuracy of the network on the test images: {netTest_acc1}% & Test Loss: {Test_loss}')
    return netTest_acc1, Test_loss

rmnist = RMNIST()
loss_func = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(rmnist.parameters(), lr=0.0001)

a=[]
for i in rmnist.parameters():
    a.append(torch.numel(i))
print('Total no of parameters in Model 1:', np.sum(a),)

train_loss_arr = []

test_loss_arr = []

epochArr = []
epochs = 1000
interval = 500
for epoch in range(1, epochs + 1):
    epochArr.append(epoch)
    loss, acc = train(rmnist, optimizer, epoch, train_loader, interval)
    train_loss_arr.append(loss.detach().numpy())
    testAcc,testloss = test(rmnist, epoch, test_loader)
    test_loss_arr.append(testloss)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# train_dataset size: 60000
# test_dataset size: 10000
# Total no of parameters in Model 1: 397510
# Train Log:Epoch: 1, Step [1/60000], TrainLoss: 2.3145
# Train Log:Epoch: 1, Step [501/60000], TrainLoss: 2.2961
# Accuracy of the network on the test images: 11.88% & Test Loss: 2.2940521955490114
# Train Log:Epoch: 2, Step [1/60000], TrainLoss: 2.2903
# Train Log:Epoch: 2, Step [501/60000], TrainLoss: 2.2930
# Accuracy of the network on the test images: 14.1% & Test Loss: 2.2895619320869445
# Train Log:Epoch: 3, Step [1/60000], TrainLoss: 2.3013
# Train Log:Epoch: 3, Step [501/60000], TrainLoss: 2.2909
# Accuracy of the network on the test images: 12.11% & Test Loss: 2.2921033668518067
# Train Log:Epoch: 4, Step [1/60000], TrainLoss: 2.2940
# Train Log:Epoch: 4, Step [501/60000], TrainLoss: 2.2983
# Accuracy of the network on the test images: 15.23% & Test Loss: 2.2840218472480776
# Train Log:Epoch: 5, Step [1/60000], TrainLoss: 2.2925
# Train Log:Epoch: 5, Step [501/60000], TrainLoss: 2.2777
# Accuracy of the network on the test images: 14.78% & Test Loss: 2.2844989323616027
# Train Log:Epoch: 6, Step [1/60000], TrainLoss: 2.2867
# Train Log:Epoch: 6, Step [501/60000], TrainLoss: 2.2774
# Accuracy of the network on the test images: 13.72% & Test Loss: 2.2881743550300597
# Train Log:Epoch: 7, Step [1/60000], TrainLoss: 2.2827
# Train Log:Epoch: 7, Step [501/60000], TrainLoss: 2.2864
# Accuracy of the network on the test images: 11.35% & Test Loss: 2.2934820103645324
# Train Log:Epoch: 8, Step [1/60000], TrainLoss: 2.2680
# Train Log:Epoch: 8, Step [501/60000], TrainLoss: 2.2696
# Accuracy of the network on the test images: 11.52% & Test Loss: 2.300457820892334
# Train Log:Epoch: 9, Step [1/60000], TrainLoss: 2.2603
# Train Log:Epoch: 9, Step [501/60000], TrainLoss: 2.2567
# Accuracy of the network on the test images: 11.32% & Test Loss: 2.302484908103943
# Train Log:Epoch: 10, Step [1/60000], TrainLoss: 2.2614
# Train Log:Epoch: 10, Step [501/60000], TrainLoss: 2.2707
# Accuracy of the network on the test images: 12.0% & Test Loss: 2.300647304058075
# Train Log:Epoch: 11, Step [1/60000], TrainLoss: 2.2605
# Train Log:Epoch: 11, Step [501/60000], TrainLoss: 2.2416
# Accuracy of the network on the test images: 12.31% & Test Loss: 2.292853739261627
# Train Log:Epoch: 12, Step [1/60000], TrainLoss: 2.2476
# Train Log:Epoch: 12, Step [501/60000], TrainLoss: 2.2541
# Accuracy of the network on the test images: 12.62% & Test Loss: 2.305799512863159
# Train Log:Epoch: 13, Step [1/60000], TrainLoss: 2.2282
# Train Log:Epoch: 13, Step [501/60000], TrainLoss: 2.2704
# Accuracy of the network on the test images: 12.81% & Test Loss: 2.291455717086792
# Train Log:Epoch: 14, Step [1/60000], TrainLoss: 2.2664
# Train Log:Epoch: 14, Step [501/60000], TrainLoss: 2.2408
# Accuracy of the network on the test images: 12.26% & Test Loss: 2.3094022727012633
# Train Log:Epoch: 15, Step [1/60000], TrainLoss: 2.1987
# Train Log:Epoch: 15, Step [501/60000], TrainLoss: 2.2613
# Accuracy of the network on the test images: 13.23% & Test Loss: 2.2932753276824953
# Train Log:Epoch: 16, Step [1/60000], TrainLoss: 2.2246
# Train Log:Epoch: 16, Step [501/60000], TrainLoss: 2.2324
# Accuracy of the network on the test images: 10.45% & Test Loss: 2.321285331249237
# Train Log:Epoch: 17, Step [1/60000], TrainLoss: 2.1758
# Train Log:Epoch: 17, Step [501/60000], TrainLoss: 2.2164
# Accuracy of the network on the test images: 11.02% & Test Loss: 2.3225500082969663
# Train Log:Epoch: 18, Step [1/60000], TrainLoss: 2.2198
# Train Log:Epoch: 18, Step [501/60000], TrainLoss: 2.2354
# Accuracy of the network on the test images: 12.66% & Test Loss: 2.300347185134888
# Train Log:Epoch: 19, Step [1/60000], TrainLoss: 2.2164
# Train Log:Epoch: 19, Step [501/60000], TrainLoss: 2.2089
# Accuracy of the network on the test images: 12.63% & Test Loss: 2.2983392763137815
# Train Log:Epoch: 20, Step [1/60000], TrainLoss: 2.1454
# Train Log:Epoch: 20, Step [501/60000], TrainLoss: 2.2147
# Accuracy of the network on the test images: 11.86% & Test Loss: 2.3137935185432434
# Train Log:Epoch: 21, Step [1/60000], TrainLoss: 2.1670
# Train Log:Epoch: 21, Step [501/60000], TrainLoss: 2.1471
# Accuracy of the network on the test images: 10.22% & Test Loss: 2.3346597170829773
# Train Log:Epoch: 22, Step [1/60000], TrainLoss: 2.2534
# Train Log:Epoch: 22, Step [501/60000], TrainLoss: 2.2225
# Accuracy of the network on the test images: 10.15% & Test Loss: 2.3306317853927614
# Train Log:Epoch: 23, Step [1/60000], TrainLoss: 2.1574
# Train Log:Epoch: 23, Step [501/60000], TrainLoss: 2.1961
# Accuracy of the network on the test images: 11.13% & Test Loss: 2.3136277174949647
# Train Log:Epoch: 24, Step [1/60000], TrainLoss: 2.1919
# Train Log:Epoch: 24, Step [501/60000], TrainLoss: 2.1863
# Accuracy of the network on the test images: 13.05% & Test Loss: 2.2930818891525266
# Train Log:Epoch: 25, Step [1/60000], TrainLoss: 2.1804
# Train Log:Epoch: 25, Step [501/60000], TrainLoss: 2.1634
# Accuracy of the network on the test images: 11.45% & Test Loss: 2.334970636367798
# Train Log:Epoch: 26, Step [1/60000], TrainLoss: 2.1569
# Train Log:Epoch: 26, Step [501/60000], TrainLoss: 2.1691
# Accuracy of the network on the test images: 12.45% & Test Loss: 2.3285180163383483
# Train Log:Epoch: 27, Step [1/60000], TrainLoss: 2.1268
# Train Log:Epoch: 27, Step [501/60000], TrainLoss: 2.2190
# Accuracy of the network on the test images: 11.22% & Test Loss: 2.328789927959442
# Train Log:Epoch: 28, Step [1/60000], TrainLoss: 2.1188
# Train Log:Epoch: 28, Step [501/60000], TrainLoss: 2.1101
# Accuracy of the network on the test images: 10.47% & Test Loss: 2.3356817674636843
# Train Log:Epoch: 29, Step [1/60000], TrainLoss: 2.1231
# Train Log:Epoch: 29, Step [501/60000], TrainLoss: 2.0914
# Accuracy of the network on the test images: 11.23% & Test Loss: 2.347846660614014
# Train Log:Epoch: 30, Step [1/60000], TrainLoss: 2.1206
# Train Log:Epoch: 30, Step [501/60000], TrainLoss: 2.0946
# Accuracy of the network on the test images: 10.68% & Test Loss: 2.3420539474487305
# Train Log:Epoch: 31, Step [1/60000], TrainLoss: 2.1367
# Train Log:Epoch: 31, Step [501/60000], TrainLoss: 2.1366
# Accuracy of the network on the test images: 10.42% & Test Loss: 2.3629230284690856
# Train Log:Epoch: 32, Step [1/60000], TrainLoss: 2.0819
# Train Log:Epoch: 32, Step [501/60000], TrainLoss: 2.1885
# Accuracy of the network on the test images: 12.06% & Test Loss: 2.3258038544654847
# Train Log:Epoch: 33, Step [1/60000], TrainLoss: 2.0824
# Train Log:Epoch: 33, Step [501/60000], TrainLoss: 2.0488
# Accuracy of the network on the test images: 9.75% & Test Loss: 2.3626035690307616
# Train Log:Epoch: 34, Step [1/60000], TrainLoss: 2.0858
# Train Log:Epoch: 34, Step [501/60000], TrainLoss: 2.1590
# Accuracy of the network on the test images: 12.64% & Test Loss: 2.3335580468177795
# Train Log:Epoch: 35, Step [1/60000], TrainLoss: 2.0393
# Train Log:Epoch: 35, Step [501/60000], TrainLoss: 2.1092
# Accuracy of the network on the test images: 11.66% & Test Loss: 2.3342626094818115
# Train Log:Epoch: 36, Step [1/60000], TrainLoss: 2.0582
# Train Log:Epoch: 36, Step [501/60000], TrainLoss: 2.1386
# Accuracy of the network on the test images: 9.9% & Test Loss: 2.3742360520362853
# Train Log:Epoch: 37, Step [1/60000], TrainLoss: 2.0907
# Train Log:Epoch: 37, Step [501/60000], TrainLoss: 2.1118
# Accuracy of the network on the test images: 10.38% & Test Loss: 2.360844655036926
# Train Log:Epoch: 38, Step [1/60000], TrainLoss: 2.0707
# Train Log:Epoch: 38, Step [501/60000], TrainLoss: 2.0920
# Accuracy of the network on the test images: 12.0% & Test Loss: 2.3466892647743225
# Train Log:Epoch: 39, Step [1/60000], TrainLoss: 2.1093
# Train Log:Epoch: 39, Step [501/60000], TrainLoss: 2.0659
# Accuracy of the network on the test images: 11.67% & Test Loss: 2.3501877999305725
# Train Log:Epoch: 40, Step [1/60000], TrainLoss: 2.0418
# Train Log:Epoch: 40, Step [501/60000], TrainLoss: 2.0380
# Accuracy of the network on the test images: 11.3% & Test Loss: 2.372010374069214
# Train Log:Epoch: 41, Step [1/60000], TrainLoss: 1.9908
# Train Log:Epoch: 41, Step [501/60000], TrainLoss: 2.0664
# Accuracy of the network on the test images: 11.46% & Test Loss: 2.354117362499237
# Train Log:Epoch: 42, Step [1/60000], TrainLoss: 2.0790
# Train Log:Epoch: 42, Step [501/60000], TrainLoss: 1.9933
# Accuracy of the network on the test images: 12.41% & Test Loss: 2.367269804477692
# Train Log:Epoch: 43, Step [1/60000], TrainLoss: 1.9458
# Train Log:Epoch: 43, Step [501/60000], TrainLoss: 2.0677
# Accuracy of the network on the test images: 11.17% & Test Loss: 2.3660699629783633
# Train Log:Epoch: 44, Step [1/60000], TrainLoss: 2.0666
# Train Log:Epoch: 44, Step [501/60000], TrainLoss: 1.9377
# Accuracy of the network on the test images: 10.16% & Test Loss: 2.3954714560508727
# Train Log:Epoch: 45, Step [1/60000], TrainLoss: 1.9513
# Train Log:Epoch: 45, Step [501/60000], TrainLoss: 1.9789
# Accuracy of the network on the test images: 11.07% & Test Loss: 2.3863742852211
# Train Log:Epoch: 46, Step [1/60000], TrainLoss: 2.0784
# Train Log:Epoch: 46, Step [501/60000], TrainLoss: 2.0355
# Accuracy of the network on the test images: 11.27% & Test Loss: 2.3785713505744934
# Train Log:Epoch: 47, Step [1/60000], TrainLoss: 1.9550
# Train Log:Epoch: 47, Step [501/60000], TrainLoss: 2.0188
# Accuracy of the network on the test images: 12.35% & Test Loss: 2.36090539932251
# Train Log:Epoch: 48, Step [1/60000], TrainLoss: 1.9709
# Train Log:Epoch: 48, Step [501/60000], TrainLoss: 1.9492
# Accuracy of the network on the test images: 10.57% & Test Loss: 2.422057647705078
# Train Log:Epoch: 49, Step [1/60000], TrainLoss: 1.8709
# Train Log:Epoch: 49, Step [501/60000], TrainLoss: 2.0516
# Accuracy of the network on the test images: 11.07% & Test Loss: 2.3896244192123413
# Train Log:Epoch: 50, Step [1/60000], TrainLoss: 1.9477
# Train Log:Epoch: 50, Step [501/60000], TrainLoss: 1.9166
# Accuracy of the network on the test images: 10.89% & Test Loss: 2.407010636329651
# Train Log:Epoch: 51, Step [1/60000], TrainLoss: 1.9679
# Train Log:Epoch: 51, Step [501/60000], TrainLoss: 1.9749
# Accuracy of the network on the test images: 11.08% & Test Loss: 2.3839465761184693
# Train Log:Epoch: 52, Step [1/60000], TrainLoss: 1.9719
# Train Log:Epoch: 52, Step [501/60000], TrainLoss: 1.9568
# Accuracy of the network on the test images: 11.88% & Test Loss: 2.3817400598526
# Train Log:Epoch: 53, Step [1/60000], TrainLoss: 1.9257
# Train Log:Epoch: 53, Step [501/60000], TrainLoss: 1.9598
# Accuracy of the network on the test images: 11.13% & Test Loss: 2.411429681777954
# Train Log:Epoch: 54, Step [1/60000], TrainLoss: 1.9153
# Train Log:Epoch: 54, Step [501/60000], TrainLoss: 1.9796
# Accuracy of the network on the test images: 10.99% & Test Loss: 2.412693717479706
# Train Log:Epoch: 55, Step [1/60000], TrainLoss: 1.8434
# Train Log:Epoch: 55, Step [501/60000], TrainLoss: 1.9247
# Accuracy of the network on the test images: 10.24% & Test Loss: 2.447979896068573
# Train Log:Epoch: 56, Step [1/60000], TrainLoss: 1.8897
# Train Log:Epoch: 56, Step [501/60000], TrainLoss: 2.0424
# Accuracy of the network on the test images: 9.85% & Test Loss: 2.439232738018036
# Train Log:Epoch: 57, Step [1/60000], TrainLoss: 1.9319
# Train Log:Epoch: 57, Step [501/60000], TrainLoss: 2.0165
# Accuracy of the network on the test images: 10.13% & Test Loss: 2.4464165449142454
# Train Log:Epoch: 58, Step [1/60000], TrainLoss: 1.9930
# Train Log:Epoch: 58, Step [501/60000], TrainLoss: 1.9627
# Accuracy of the network on the test images: 10.74% & Test Loss: 2.4170266008377075
# Train Log:Epoch: 59, Step [1/60000], TrainLoss: 1.9922
# Train Log:Epoch: 59, Step [501/60000], TrainLoss: 1.9331
# Accuracy of the network on the test images: 11.39% & Test Loss: 2.4402781438827517
# Train Log:Epoch: 60, Step [1/60000], TrainLoss: 1.9111
# Train Log:Epoch: 60, Step [501/60000], TrainLoss: 1.9276
# Accuracy of the network on the test images: 10.74% & Test Loss: 2.429284975528717
# Train Log:Epoch: 61, Step [1/60000], TrainLoss: 1.9389
# Train Log:Epoch: 61, Step [501/60000], TrainLoss: 1.9253
# Accuracy of the network on the test images: 11.19% & Test Loss: 2.4455887341499327
# Train Log:Epoch: 62, Step [1/60000], TrainLoss: 1.8388
# Train Log:Epoch: 62, Step [501/60000], TrainLoss: 2.0325
# Accuracy of the network on the test images: 10.83% & Test Loss: 2.44093585729599
# Train Log:Epoch: 63, Step [1/60000], TrainLoss: 1.8695
# Train Log:Epoch: 63, Step [501/60000], TrainLoss: 1.8705
# Accuracy of the network on the test images: 10.72% & Test Loss: 2.464948449134827
# Train Log:Epoch: 64, Step [1/60000], TrainLoss: 1.9276
# Train Log:Epoch: 64, Step [501/60000], TrainLoss: 1.8654
# Accuracy of the network on the test images: 10.7% & Test Loss: 2.4508042621612547
# Train Log:Epoch: 65, Step [1/60000], TrainLoss: 1.8684
# Train Log:Epoch: 65, Step [501/60000], TrainLoss: 1.8439
# Accuracy of the network on the test images: 11.3% & Test Loss: 2.4357652640342713
# Train Log:Epoch: 66, Step [1/60000], TrainLoss: 1.8765
# Train Log:Epoch: 66, Step [501/60000], TrainLoss: 1.8172
# Accuracy of the network on the test images: 9.64% & Test Loss: 2.497765130996704
# Train Log:Epoch: 67, Step [1/60000], TrainLoss: 1.8804
# Train Log:Epoch: 67, Step [501/60000], TrainLoss: 1.8408
# Accuracy of the network on the test images: 11.34% & Test Loss: 2.471679458618164
# Train Log:Epoch: 68, Step [1/60000], TrainLoss: 1.7488
# Train Log:Epoch: 68, Step [501/60000], TrainLoss: 1.8970
# Accuracy of the network on the test images: 10.94% & Test Loss: 2.4600578022003172
# Train Log:Epoch: 69, Step [1/60000], TrainLoss: 1.8300
# Train Log:Epoch: 69, Step [501/60000], TrainLoss: 1.9464
# Accuracy of the network on the test images: 11.03% & Test Loss: 2.4634768629074095
# Train Log:Epoch: 70, Step [1/60000], TrainLoss: 1.8210
# Train Log:Epoch: 70, Step [501/60000], TrainLoss: 1.8018
# Accuracy of the network on the test images: 9.97% & Test Loss: 2.492860996723175
# Train Log:Epoch: 71, Step [1/60000], TrainLoss: 1.8095
# Train Log:Epoch: 71, Step [501/60000], TrainLoss: 1.7781
# Accuracy of the network on the test images: 10.81% & Test Loss: 2.4728269362449646
# Train Log:Epoch: 72, Step [1/60000], TrainLoss: 1.8461
# Train Log:Epoch: 72, Step [501/60000], TrainLoss: 1.8712
# Accuracy of the network on the test images: 9.55% & Test Loss: 2.5207884430885317
# Train Log:Epoch: 73, Step [1/60000], TrainLoss: 1.8177
# Train Log:Epoch: 73, Step [501/60000], TrainLoss: 1.8500
# Accuracy of the network on the test images: 11.79% & Test Loss: 2.4964686679840087
# Train Log:Epoch: 74, Step [1/60000], TrainLoss: 1.7405
# Train Log:Epoch: 74, Step [501/60000], TrainLoss: 1.8582
# Accuracy of the network on the test images: 10.42% & Test Loss: 2.5089130759239198
# Train Log:Epoch: 75, Step [1/60000], TrainLoss: 1.8024
# Train Log:Epoch: 75, Step [501/60000], TrainLoss: 1.9108
# Accuracy of the network on the test images: 10.63% & Test Loss: 2.500987448692322
# Train Log:Epoch: 76, Step [1/60000], TrainLoss: 1.9098
# Train Log:Epoch: 76, Step [501/60000], TrainLoss: 1.8076
# Accuracy of the network on the test images: 10.39% & Test Loss: 2.533206250667572
# Train Log:Epoch: 77, Step [1/60000], TrainLoss: 1.7918
# Train Log:Epoch: 77, Step [501/60000], TrainLoss: 1.8405
# Accuracy of the network on the test images: 10.16% & Test Loss: 2.536684377193451
# Train Log:Epoch: 78, Step [1/60000], TrainLoss: 1.7235
# Train Log:Epoch: 78, Step [501/60000], TrainLoss: 1.7275
# Accuracy of the network on the test images: 10.72% & Test Loss: 2.5089689350128173
# Train Log:Epoch: 79, Step [1/60000], TrainLoss: 1.7626
# Train Log:Epoch: 79, Step [501/60000], TrainLoss: 1.8282
# Accuracy of the network on the test images: 10.31% & Test Loss: 2.5374357080459595
# Train Log:Epoch: 80, Step [1/60000], TrainLoss: 1.8763
# Train Log:Epoch: 80, Step [501/60000], TrainLoss: 1.9521
# Accuracy of the network on the test images: 10.09% & Test Loss: 2.5282303166389464
# Train Log:Epoch: 81, Step [1/60000], TrainLoss: 1.7812
# Train Log:Epoch: 81, Step [501/60000], TrainLoss: 1.7750
# Accuracy of the network on the test images: 10.1% & Test Loss: 2.5566216135025024
# Train Log:Epoch: 82, Step [1/60000], TrainLoss: 1.6203
# Train Log:Epoch: 82, Step [501/60000], TrainLoss: 1.8496
# Accuracy of the network on the test images: 10.36% & Test Loss: 2.5367531394958496
# Train Log:Epoch: 83, Step [1/60000], TrainLoss: 1.8479
# Train Log:Epoch: 83, Step [501/60000], TrainLoss: 1.8145
# Accuracy of the network on the test images: 10.81% & Test Loss: 2.55613979101181
# Train Log:Epoch: 84, Step [1/60000], TrainLoss: 1.6812
# Train Log:Epoch: 84, Step [501/60000], TrainLoss: 1.6810
# Accuracy of the network on the test images: 10.99% & Test Loss: 2.5317464470863342
# Train Log:Epoch: 85, Step [1/60000], TrainLoss: 1.7467
# Train Log:Epoch: 85, Step [501/60000], TrainLoss: 1.6737
# Accuracy of the network on the test images: 12.26% & Test Loss: 2.499550926685333
# Train Log:Epoch: 86, Step [1/60000], TrainLoss: 1.7551
# Train Log:Epoch: 86, Step [501/60000], TrainLoss: 1.7052
# Accuracy of the network on the test images: 10.95% & Test Loss: 2.534903528690338
# Train Log:Epoch: 87, Step [1/60000], TrainLoss: 1.7483
# Train Log:Epoch: 87, Step [501/60000], TrainLoss: 1.8577
# Accuracy of the network on the test images: 9.91% & Test Loss: 2.587331562042236
# Train Log:Epoch: 88, Step [1/60000], TrainLoss: 1.6308
# Train Log:Epoch: 88, Step [501/60000], TrainLoss: 1.6628
# Accuracy of the network on the test images: 9.94% & Test Loss: 2.576952049732208
# Train Log:Epoch: 89, Step [1/60000], TrainLoss: 1.6612
# Train Log:Epoch: 89, Step [501/60000], TrainLoss: 1.7431
# Accuracy of the network on the test images: 10.4% & Test Loss: 2.581774933338165
# Train Log:Epoch: 90, Step [1/60000], TrainLoss: 1.7368
# Train Log:Epoch: 90, Step [501/60000], TrainLoss: 1.7300
# Accuracy of the network on the test images: 11.47% & Test Loss: 2.54391135931015
# Train Log:Epoch: 91, Step [1/60000], TrainLoss: 1.7210
# Train Log:Epoch: 91, Step [501/60000], TrainLoss: 1.8382
# Accuracy of the network on the test images: 10.65% & Test Loss: 2.566902279853821
# Train Log:Epoch: 92, Step [1/60000], TrainLoss: 1.7175
# Train Log:Epoch: 92, Step [501/60000], TrainLoss: 1.6637
# Accuracy of the network on the test images: 10.88% & Test Loss: 2.572291445732117
# Train Log:Epoch: 93, Step [1/60000], TrainLoss: 1.7702
# Train Log:Epoch: 93, Step [501/60000], TrainLoss: 1.7275
# Accuracy of the network on the test images: 10.16% & Test Loss: 2.6043611359596253
# Train Log:Epoch: 94, Step [1/60000], TrainLoss: 1.6754
# Train Log:Epoch: 94, Step [501/60000], TrainLoss: 1.6875
# Accuracy of the network on the test images: 11.55% & Test Loss: 2.565186381340027
# Train Log:Epoch: 95, Step [1/60000], TrainLoss: 1.7520
# Train Log:Epoch: 95, Step [501/60000], TrainLoss: 1.6708
# Accuracy of the network on the test images: 10.42% & Test Loss: 2.6012251806259155
# Train Log:Epoch: 96, Step [1/60000], TrainLoss: 1.6404
# Train Log:Epoch: 96, Step [501/60000], TrainLoss: 1.7419
# Accuracy of the network on the test images: 10.19% & Test Loss: 2.619556589126587
# Train Log:Epoch: 97, Step [1/60000], TrainLoss: 1.6631
# Train Log:Epoch: 97, Step [501/60000], TrainLoss: 1.6211
# Accuracy of the network on the test images: 10.24% & Test Loss: 2.6314730143547056
# Train Log:Epoch: 98, Step [1/60000], TrainLoss: 1.6671
# Train Log:Epoch: 98, Step [501/60000], TrainLoss: 1.6903
# Accuracy of the network on the test images: 10.16% & Test Loss: 2.6275996279716494
# Train Log:Epoch: 99, Step [1/60000], TrainLoss: 1.5323
# Train Log:Epoch: 99, Step [501/60000], TrainLoss: 1.7376
# Accuracy of the network on the test images: 10.07% & Test Loss: 2.617994103431702
# Train Log:Epoch: 100, Step [1/60000], TrainLoss: 1.7193
# Train Log:Epoch: 100, Step [501/60000], TrainLoss: 1.7313
# Accuracy of the network on the test images: 10.61% & Test Loss: 2.6206308794021607
# Train Log:Epoch: 101, Step [1/60000], TrainLoss: 1.5297
# Train Log:Epoch: 101, Step [501/60000], TrainLoss: 1.7716
# Accuracy of the network on the test images: 11.88% & Test Loss: 2.610736994743347
# Train Log:Epoch: 102, Step [1/60000], TrainLoss: 1.6959
# Train Log:Epoch: 102, Step [501/60000], TrainLoss: 1.6356
# Accuracy of the network on the test images: 10.29% & Test Loss: 2.631302819252014
# Train Log:Epoch: 103, Step [1/60000], TrainLoss: 1.6800
# Train Log:Epoch: 103, Step [501/60000], TrainLoss: 1.5792
# Accuracy of the network on the test images: 11.0% & Test Loss: 2.614458258152008
# Train Log:Epoch: 104, Step [1/60000], TrainLoss: 1.4856
# Train Log:Epoch: 104, Step [501/60000], TrainLoss: 1.6996
# Accuracy of the network on the test images: 11.3% & Test Loss: 2.6299312615394594
# Train Log:Epoch: 105, Step [1/60000], TrainLoss: 1.5962
# Train Log:Epoch: 105, Step [501/60000], TrainLoss: 1.7076
# Accuracy of the network on the test images: 10.29% & Test Loss: 2.659897062778473
# Train Log:Epoch: 106, Step [1/60000], TrainLoss: 1.5529
# Train Log:Epoch: 106, Step [501/60000], TrainLoss: 1.3636
# Accuracy of the network on the test images: 10.42% & Test Loss: 2.6457179498672487
# Train Log:Epoch: 107, Step [1/60000], TrainLoss: 1.5457
# Train Log:Epoch: 107, Step [501/60000], TrainLoss: 1.6819
# Accuracy of the network on the test images: 10.23% & Test Loss: 2.67833713054657
# Train Log:Epoch: 108, Step [1/60000], TrainLoss: 1.5674
# Train Log:Epoch: 108, Step [501/60000], TrainLoss: 1.6390
# Accuracy of the network on the test images: 11.36% & Test Loss: 2.634588921070099
# Train Log:Epoch: 109, Step [1/60000], TrainLoss: 1.5932
# Train Log:Epoch: 109, Step [501/60000], TrainLoss: 1.5713
# Accuracy of the network on the test images: 10.64% & Test Loss: 2.663831744194031
# Train Log:Epoch: 110, Step [1/60000], TrainLoss: 1.5471
# Train Log:Epoch: 110, Step [501/60000], TrainLoss: 1.6304
# Accuracy of the network on the test images: 10.46% & Test Loss: 2.6661931037902833
# Train Log:Epoch: 111, Step [1/60000], TrainLoss: 1.5362
# Train Log:Epoch: 111, Step [501/60000], TrainLoss: 1.5535
# Accuracy of the network on the test images: 10.68% & Test Loss: 2.6749179315567018
# Train Log:Epoch: 112, Step [1/60000], TrainLoss: 1.6162
# Train Log:Epoch: 112, Step [501/60000], TrainLoss: 1.6555
# Accuracy of the network on the test images: 10.81% & Test Loss: 2.686850895881653
# Train Log:Epoch: 113, Step [1/60000], TrainLoss: 1.6019
# Train Log:Epoch: 113, Step [501/60000], TrainLoss: 1.5999
# Accuracy of the network on the test images: 9.45% & Test Loss: 2.719958815574646
# Train Log:Epoch: 114, Step [1/60000], TrainLoss: 1.5935
# Train Log:Epoch: 114, Step [501/60000], TrainLoss: 1.5890
# Accuracy of the network on the test images: 10.17% & Test Loss: 2.709273359775543
# Train Log:Epoch: 115, Step [1/60000], TrainLoss: 1.6178
# Train Log:Epoch: 115, Step [501/60000], TrainLoss: 1.5877
# Accuracy of the network on the test images: 10.94% & Test Loss: 2.689141833782196
# Train Log:Epoch: 116, Step [1/60000], TrainLoss: 1.6874
# Train Log:Epoch: 116, Step [501/60000], TrainLoss: 1.6241
# Accuracy of the network on the test images: 10.6% & Test Loss: 2.6653045439720153
# Train Log:Epoch: 117, Step [1/60000], TrainLoss: 1.5511
# Train Log:Epoch: 117, Step [501/60000], TrainLoss: 1.4664
# Accuracy of the network on the test images: 11.18% & Test Loss: 2.6902011752128603
# Train Log:Epoch: 118, Step [1/60000], TrainLoss: 1.3998
# Train Log:Epoch: 118, Step [501/60000], TrainLoss: 1.5617
# Accuracy of the network on the test images: 10.26% & Test Loss: 2.7112017345428465
# Train Log:Epoch: 119, Step [1/60000], TrainLoss: 1.6399
# Train Log:Epoch: 119, Step [501/60000], TrainLoss: 1.6021
# Accuracy of the network on the test images: 12.02% & Test Loss: 2.649607527256012
# Train Log:Epoch: 120, Step [1/60000], TrainLoss: 1.5098
# Train Log:Epoch: 120, Step [501/60000], TrainLoss: 1.4779
# Accuracy of the network on the test images: 10.17% & Test Loss: 2.755292899608612
# Train Log:Epoch: 121, Step [1/60000], TrainLoss: 1.4234
# Train Log:Epoch: 121, Step [501/60000], TrainLoss: 1.5675
# Accuracy of the network on the test images: 10.62% & Test Loss: 2.72498162984848
# Train Log:Epoch: 122, Step [1/60000], TrainLoss: 1.5393
# Train Log:Epoch: 122, Step [501/60000], TrainLoss: 1.5051
# Accuracy of the network on the test images: 10.75% & Test Loss: 2.7293829917907715
# Train Log:Epoch: 123, Step [1/60000], TrainLoss: 1.5435
# Train Log:Epoch: 123, Step [501/60000], TrainLoss: 1.4539
# Accuracy of the network on the test images: 11.32% & Test Loss: 2.71034387588501
# Train Log:Epoch: 124, Step [1/60000], TrainLoss: 1.4803
# Train Log:Epoch: 124, Step [501/60000], TrainLoss: 1.5499
# Accuracy of the network on the test images: 9.96% & Test Loss: 2.768530056476593
# Train Log:Epoch: 125, Step [1/60000], TrainLoss: 1.4793
# Train Log:Epoch: 125, Step [501/60000], TrainLoss: 1.5259
# Accuracy of the network on the test images: 10.23% & Test Loss: 2.741124770641327
# Train Log:Epoch: 126, Step [1/60000], TrainLoss: 1.4394
# Train Log:Epoch: 126, Step [501/60000], TrainLoss: 1.3796
# Accuracy of the network on the test images: 10.8% & Test Loss: 2.7543407225608827
# Train Log:Epoch: 127, Step [1/60000], TrainLoss: 1.4970
# Train Log:Epoch: 127, Step [501/60000], TrainLoss: 1.5972
# Accuracy of the network on the test images: 11.14% & Test Loss: 2.714825618267059
# Train Log:Epoch: 128, Step [1/60000], TrainLoss: 1.4536
# Train Log:Epoch: 128, Step [501/60000], TrainLoss: 1.4827
# Accuracy of the network on the test images: 10.14% & Test Loss: 2.792312054634094
# Train Log:Epoch: 129, Step [1/60000], TrainLoss: 1.5293
# Train Log:Epoch: 129, Step [501/60000], TrainLoss: 1.5055
# Accuracy of the network on the test images: 10.45% & Test Loss: 2.7835087418556212
# Train Log:Epoch: 130, Step [1/60000], TrainLoss: 1.5800
# Train Log:Epoch: 130, Step [501/60000], TrainLoss: 1.6221
# Accuracy of the network on the test images: 10.68% & Test Loss: 2.766820945739746
# Train Log:Epoch: 131, Step [1/60000], TrainLoss: 1.3247
# Train Log:Epoch: 131, Step [501/60000], TrainLoss: 1.4742
# Accuracy of the network on the test images: 10.03% & Test Loss: 2.7844605660438537
# Train Log:Epoch: 132, Step [1/60000], TrainLoss: 1.4996
# Train Log:Epoch: 132, Step [501/60000], TrainLoss: 1.4923
# Accuracy of the network on the test images: 10.14% & Test Loss: 2.81987877368927
# Train Log:Epoch: 133, Step [1/60000], TrainLoss: 1.5935
# Train Log:Epoch: 133, Step [501/60000], TrainLoss: 1.4459
# Accuracy of the network on the test images: 11.2% & Test Loss: 2.7700475573539736
# Train Log:Epoch: 134, Step [1/60000], TrainLoss: 1.4984
# Train Log:Epoch: 134, Step [501/60000], TrainLoss: 1.5961
# Accuracy of the network on the test images: 10.45% & Test Loss: 2.808167519569397
# Train Log:Epoch: 135, Step [1/60000], TrainLoss: 1.4148
# Train Log:Epoch: 135, Step [501/60000], TrainLoss: 1.5831
# Accuracy of the network on the test images: 11.27% & Test Loss: 2.7554113054275513
# Train Log:Epoch: 136, Step [1/60000], TrainLoss: 1.4405
# Train Log:Epoch: 136, Step [501/60000], TrainLoss: 1.3902
# Accuracy of the network on the test images: 10.07% & Test Loss: 2.8139197754859926
# Train Log:Epoch: 137, Step [1/60000], TrainLoss: 1.3701
# Train Log:Epoch: 137, Step [501/60000], TrainLoss: 1.4907
# Accuracy of the network on the test images: 9.79% & Test Loss: 2.8419440364837647
# Train Log:Epoch: 138, Step [1/60000], TrainLoss: 1.4422
# Train Log:Epoch: 138, Step [501/60000], TrainLoss: 1.4343
# Accuracy of the network on the test images: 10.63% & Test Loss: 2.8198106479644776
# Train Log:Epoch: 139, Step [1/60000], TrainLoss: 1.3914
# Train Log:Epoch: 139, Step [501/60000], TrainLoss: 1.4051
# Accuracy of the network on the test images: 10.57% & Test Loss: 2.8080784344673155
# Train Log:Epoch: 140, Step [1/60000], TrainLoss: 1.3622
# Train Log:Epoch: 140, Step [501/60000], TrainLoss: 1.5535
# Accuracy of the network on the test images: 10.77% & Test Loss: 2.8246960115432738
# Train Log:Epoch: 141, Step [1/60000], TrainLoss: 1.3555
# Train Log:Epoch: 141, Step [501/60000], TrainLoss: 1.4331
# Accuracy of the network on the test images: 10.4% & Test Loss: 2.860230438709259
# Train Log:Epoch: 142, Step [1/60000], TrainLoss: 1.4427
# Train Log:Epoch: 142, Step [501/60000], TrainLoss: 1.3959
# Accuracy of the network on the test images: 11.69% & Test Loss: 2.7833447813987733
# Train Log:Epoch: 143, Step [1/60000], TrainLoss: 1.3855
# Train Log:Epoch: 143, Step [501/60000], TrainLoss: 1.4028
# Accuracy of the network on the test images: 10.21% & Test Loss: 2.8815887475013735
# Train Log:Epoch: 144, Step [1/60000], TrainLoss: 1.4325
# Train Log:Epoch: 144, Step [501/60000], TrainLoss: 1.2905
# Accuracy of the network on the test images: 10.34% & Test Loss: 2.841117594242096
# Train Log:Epoch: 145, Step [1/60000], TrainLoss: 1.1742
# Train Log:Epoch: 145, Step [501/60000], TrainLoss: 1.4460
# Accuracy of the network on the test images: 10.95% & Test Loss: 2.8304092359542845
# Train Log:Epoch: 146, Step [1/60000], TrainLoss: 1.3355
# Train Log:Epoch: 146, Step [501/60000], TrainLoss: 1.4933
# Accuracy of the network on the test images: 10.01% & Test Loss: 2.869113290309906
# Train Log:Epoch: 147, Step [1/60000], TrainLoss: 1.3843
# Train Log:Epoch: 147, Step [501/60000], TrainLoss: 1.4774
# Accuracy of the network on the test images: 10.87% & Test Loss: 2.854164559841156
# Train Log:Epoch: 148, Step [1/60000], TrainLoss: 1.3381
# Train Log:Epoch: 148, Step [501/60000], TrainLoss: 1.3699
# Accuracy of the network on the test images: 9.76% & Test Loss: 2.92178612947464
# Train Log:Epoch: 149, Step [1/60000], TrainLoss: 1.3335
# Train Log:Epoch: 149, Step [501/60000], TrainLoss: 1.4207
# Accuracy of the network on the test images: 10.65% & Test Loss: 2.8805537819862366
# Train Log:Epoch: 150, Step [1/60000], TrainLoss: 1.4676
# Train Log:Epoch: 150, Step [501/60000], TrainLoss: 1.4175
# Accuracy of the network on the test images: 11.62% & Test Loss: 2.830345962047577
# Train Log:Epoch: 151, Step [1/60000], TrainLoss: 1.3035
# Train Log:Epoch: 151, Step [501/60000], TrainLoss: 1.4874
# Accuracy of the network on the test images: 10.71% & Test Loss: 2.869728436470032
# Train Log:Epoch: 152, Step [1/60000], TrainLoss: 1.3426
# Train Log:Epoch: 152, Step [501/60000], TrainLoss: 1.3699
# Accuracy of the network on the test images: 10.16% & Test Loss: 2.904856061935425
# Train Log:Epoch: 153, Step [1/60000], TrainLoss: 1.3158
# Train Log:Epoch: 153, Step [501/60000], TrainLoss: 1.3459
# Accuracy of the network on the test images: 11.42% & Test Loss: 2.8540381145477296
# Train Log:Epoch: 154, Step [1/60000], TrainLoss: 1.2929
# Train Log:Epoch: 154, Step [501/60000], TrainLoss: 1.5458
# Accuracy of the network on the test images: 10.76% & Test Loss: 2.902426266670227
# Train Log:Epoch: 155, Step [1/60000], TrainLoss: 1.3286
# Train Log:Epoch: 155, Step [501/60000], TrainLoss: 1.3844
# Accuracy of the network on the test images: 10.47% & Test Loss: 2.885169644355774
# Train Log:Epoch: 156, Step [1/60000], TrainLoss: 1.3576
# Train Log:Epoch: 156, Step [501/60000], TrainLoss: 1.5201
# Accuracy of the network on the test images: 10.74% & Test Loss: 2.892171359062195
# Train Log:Epoch: 157, Step [1/60000], TrainLoss: 1.2297
# Train Log:Epoch: 157, Step [501/60000], TrainLoss: 1.3948
# Accuracy of the network on the test images: 11.0% & Test Loss: 2.859293110370636
# Train Log:Epoch: 158, Step [1/60000], TrainLoss: 1.3577
# Train Log:Epoch: 158, Step [501/60000], TrainLoss: 1.4447
# Accuracy of the network on the test images: 10.99% & Test Loss: 2.909420676231384
# Train Log:Epoch: 159, Step [1/60000], TrainLoss: 1.3301
# Train Log:Epoch: 159, Step [501/60000], TrainLoss: 1.4058
# Accuracy of the network on the test images: 10.53% & Test Loss: 2.9616165566444397
# Train Log:Epoch: 160, Step [1/60000], TrainLoss: 1.2836
# Train Log:Epoch: 160, Step [501/60000], TrainLoss: 1.4895
# Accuracy of the network on the test images: 9.93% & Test Loss: 2.9546536469459532
# Train Log:Epoch: 161, Step [1/60000], TrainLoss: 1.2146
# Train Log:Epoch: 161, Step [501/60000], TrainLoss: 1.3210
# Accuracy of the network on the test images: 10.04% & Test Loss: 2.949720904827118
# Train Log:Epoch: 162, Step [1/60000], TrainLoss: 1.2887
# Train Log:Epoch: 162, Step [501/60000], TrainLoss: 1.1898
# Accuracy of the network on the test images: 12.3% & Test Loss: 2.899734435081482
# Train Log:Epoch: 163, Step [1/60000], TrainLoss: 1.3423
# Train Log:Epoch: 163, Step [501/60000], TrainLoss: 1.3027
# Accuracy of the network on the test images: 9.92% & Test Loss: 2.973848752975464
# Train Log:Epoch: 164, Step [1/60000], TrainLoss: 1.3116
# Train Log:Epoch: 164, Step [501/60000], TrainLoss: 1.3686
# Accuracy of the network on the test images: 9.63% & Test Loss: 2.9777357840538023
# Train Log:Epoch: 165, Step [1/60000], TrainLoss: 1.1489
# Train Log:Epoch: 165, Step [501/60000], TrainLoss: 1.3100
# Accuracy of the network on the test images: 10.72% & Test Loss: 2.98642174243927
# Train Log:Epoch: 166, Step [1/60000], TrainLoss: 1.2822
# Train Log:Epoch: 166, Step [501/60000], TrainLoss: 1.4117
# Accuracy of the network on the test images: 10.12% & Test Loss: 3.005050685405731
# Train Log:Epoch: 167, Step [1/60000], TrainLoss: 1.2653
# Train Log:Epoch: 167, Step [501/60000], TrainLoss: 1.3600
# Accuracy of the network on the test images: 10.93% & Test Loss: 2.9526724576950074
# Train Log:Epoch: 168, Step [1/60000], TrainLoss: 1.3950
# Train Log:Epoch: 168, Step [501/60000], TrainLoss: 1.2648
# Accuracy of the network on the test images: 10.86% & Test Loss: 2.9846176671981812
# Train Log:Epoch: 169, Step [1/60000], TrainLoss: 1.3170
# Train Log:Epoch: 169, Step [501/60000], TrainLoss: 1.4056
# Accuracy of the network on the test images: 11.67% & Test Loss: 2.916610734462738
# Train Log:Epoch: 170, Step [1/60000], TrainLoss: 1.3891
# Train Log:Epoch: 170, Step [501/60000], TrainLoss: 1.1843
# Accuracy of the network on the test images: 11.49% & Test Loss: 2.9657023882865907
# Train Log:Epoch: 171, Step [1/60000], TrainLoss: 1.1824
# Train Log:Epoch: 171, Step [501/60000], TrainLoss: 1.1443
# Accuracy of the network on the test images: 10.7% & Test Loss: 2.9909717559814455
# Train Log:Epoch: 172, Step [1/60000], TrainLoss: 1.2691
# Train Log:Epoch: 172, Step [501/60000], TrainLoss: 1.2886
# Accuracy of the network on the test images: 11.44% & Test Loss: 2.967510085105896
# Train Log:Epoch: 173, Step [1/60000], TrainLoss: 1.1015
# Train Log:Epoch: 173, Step [501/60000], TrainLoss: 1.2859
# Accuracy of the network on the test images: 10.33% & Test Loss: 2.9957791471481325
# Train Log:Epoch: 174, Step [1/60000], TrainLoss: 1.2064
# Train Log:Epoch: 174, Step [501/60000], TrainLoss: 1.2979
# Accuracy of the network on the test images: 10.5% & Test Loss: 3.0137166142463685
# Train Log:Epoch: 175, Step [1/60000], TrainLoss: 1.3427
# Train Log:Epoch: 175, Step [501/60000], TrainLoss: 1.2786
# Accuracy of the network on the test images: 11.23% & Test Loss: 2.998754570484161
# Train Log:Epoch: 176, Step [1/60000], TrainLoss: 1.2152
# Train Log:Epoch: 176, Step [501/60000], TrainLoss: 1.2916
# Accuracy of the network on the test images: 11.16% & Test Loss: 3.0409203934669495
# Train Log:Epoch: 177, Step [1/60000], TrainLoss: 1.2626
# Train Log:Epoch: 177, Step [501/60000], TrainLoss: 1.2648
# Accuracy of the network on the test images: 10.38% & Test Loss: 3.042699944972992
# Train Log:Epoch: 178, Step [1/60000], TrainLoss: 1.1454
# Train Log:Epoch: 178, Step [501/60000], TrainLoss: 1.3445
# Accuracy of the network on the test images: 10.6% & Test Loss: 3.016658699512482
# Train Log:Epoch: 179, Step [1/60000], TrainLoss: 1.1350
# Train Log:Epoch: 179, Step [501/60000], TrainLoss: 1.2544
# Accuracy of the network on the test images: 9.81% & Test Loss: 3.0890114402770994
# Train Log:Epoch: 180, Step [1/60000], TrainLoss: 1.2179
# Train Log:Epoch: 180, Step [501/60000], TrainLoss: 1.2425
# Accuracy of the network on the test images: 10.01% & Test Loss: 3.0594555068016054
# Train Log:Epoch: 181, Step [1/60000], TrainLoss: 1.3998
# Train Log:Epoch: 181, Step [501/60000], TrainLoss: 1.1198
# Accuracy of the network on the test images: 11.14% & Test Loss: 3.054853000640869
# Train Log:Epoch: 182, Step [1/60000], TrainLoss: 1.1085
# Train Log:Epoch: 182, Step [501/60000], TrainLoss: 1.2767
# Accuracy of the network on the test images: 11.34% & Test Loss: 3.044516746997833
# Train Log:Epoch: 183, Step [1/60000], TrainLoss: 1.3439
# Train Log:Epoch: 183, Step [501/60000], TrainLoss: 1.3972
# Accuracy of the network on the test images: 10.03% & Test Loss: 3.08454407453537
# Train Log:Epoch: 184, Step [1/60000], TrainLoss: 1.2340
# Train Log:Epoch: 184, Step [501/60000], TrainLoss: 1.3476
# Accuracy of the network on the test images: 9.68% & Test Loss: 3.1427699637413027
# Train Log:Epoch: 185, Step [1/60000], TrainLoss: 1.1541
# Train Log:Epoch: 185, Step [501/60000], TrainLoss: 1.2618
# Accuracy of the network on the test images: 10.44% & Test Loss: 3.083875529766083
# Train Log:Epoch: 186, Step [1/60000], TrainLoss: 1.2694
# Train Log:Epoch: 186, Step [501/60000], TrainLoss: 1.3822
# Accuracy of the network on the test images: 11.83% & Test Loss: 3.0343288493156435
# Train Log:Epoch: 187, Step [1/60000], TrainLoss: 1.1752
# Train Log:Epoch: 187, Step [501/60000], TrainLoss: 1.3812
# Accuracy of the network on the test images: 11.19% & Test Loss: 3.1019229459762574
# Train Log:Epoch: 188, Step [1/60000], TrainLoss: 1.1747
# Train Log:Epoch: 188, Step [501/60000], TrainLoss: 1.1757
# Accuracy of the network on the test images: 10.83% & Test Loss: 3.0906232452392577
# Train Log:Epoch: 189, Step [1/60000], TrainLoss: 1.1723
# Train Log:Epoch: 189, Step [501/60000], TrainLoss: 1.1223
# Accuracy of the network on the test images: 10.44% & Test Loss: 3.0965146470069884
# Train Log:Epoch: 190, Step [1/60000], TrainLoss: 1.2723
# Train Log:Epoch: 190, Step [501/60000], TrainLoss: 1.3536
# Accuracy of the network on the test images: 10.69% & Test Loss: 3.107530624866486
# Train Log:Epoch: 191, Step [1/60000], TrainLoss: 1.1228
# Train Log:Epoch: 191, Step [501/60000], TrainLoss: 1.2522
# Accuracy of the network on the test images: 11.09% & Test Loss: 3.088852388858795
# Train Log:Epoch: 192, Step [1/60000], TrainLoss: 1.0491
# Train Log:Epoch: 192, Step [501/60000], TrainLoss: 1.1910
# Accuracy of the network on the test images: 10.18% & Test Loss: 3.13549560546875
# Train Log:Epoch: 193, Step [1/60000], TrainLoss: 1.1198
# Train Log:Epoch: 193, Step [501/60000], TrainLoss: 1.1083
# Accuracy of the network on the test images: 10.71% & Test Loss: 3.113063061237335
# Train Log:Epoch: 194, Step [1/60000], TrainLoss: 1.2030
# Train Log:Epoch: 194, Step [501/60000], TrainLoss: 1.2481
# Accuracy of the network on the test images: 11.0% & Test Loss: 3.1139797973632812
# Train Log:Epoch: 195, Step [1/60000], TrainLoss: 1.1646
# Train Log:Epoch: 195, Step [501/60000], TrainLoss: 1.1624
# Accuracy of the network on the test images: 11.18% & Test Loss: 3.084395852088928
# Train Log:Epoch: 196, Step [1/60000], TrainLoss: 1.1685
# Train Log:Epoch: 196, Step [501/60000], TrainLoss: 1.1420
# Accuracy of the network on the test images: 9.86% & Test Loss: 3.171542139053345
# Train Log:Epoch: 197, Step [1/60000], TrainLoss: 1.1785
# Train Log:Epoch: 197, Step [501/60000], TrainLoss: 1.2354
# Accuracy of the network on the test images: 10.39% & Test Loss: 3.121915965080261
# Train Log:Epoch: 198, Step [1/60000], TrainLoss: 1.0159
# Train Log:Epoch: 198, Step [501/60000], TrainLoss: 1.1386
# Accuracy of the network on the test images: 10.57% & Test Loss: 3.143939445018768
# Train Log:Epoch: 199, Step [1/60000], TrainLoss: 1.1579
# Train Log:Epoch: 199, Step [501/60000], TrainLoss: 1.1147
# Accuracy of the network on the test images: 10.84% & Test Loss: 3.1237162566184997
# Train Log:Epoch: 200, Step [1/60000], TrainLoss: 1.0274
# Train Log:Epoch: 200, Step [501/60000], TrainLoss: 1.1469
# Accuracy of the network on the test images: 9.77% & Test Loss: 3.2015089702606203
# Train Log:Epoch: 201, Step [1/60000], TrainLoss: 1.1144
# Train Log:Epoch: 201, Step [501/60000], TrainLoss: 1.1324
# Accuracy of the network on the test images: 10.01% & Test Loss: 3.191593356132507
# Train Log:Epoch: 202, Step [1/60000], TrainLoss: 1.1440
# Train Log:Epoch: 202, Step [501/60000], TrainLoss: 1.2701
# Accuracy of the network on the test images: 10.28% & Test Loss: 3.15897442817688
# Train Log:Epoch: 203, Step [1/60000], TrainLoss: 1.0351
# Train Log:Epoch: 203, Step [501/60000], TrainLoss: 1.0960
# Accuracy of the network on the test images: 10.69% & Test Loss: 3.1622315645217896
# Train Log:Epoch: 204, Step [1/60000], TrainLoss: 1.1597
# Train Log:Epoch: 204, Step [501/60000], TrainLoss: 1.1737
# Accuracy of the network on the test images: 11.04% & Test Loss: 3.1552051210403445
# Train Log:Epoch: 205, Step [1/60000], TrainLoss: 1.2149
# Train Log:Epoch: 205, Step [501/60000], TrainLoss: 1.0883
# Accuracy of the network on the test images: 9.43% & Test Loss: 3.2660755491256714
# Train Log:Epoch: 206, Step [1/60000], TrainLoss: 1.1406
# Train Log:Epoch: 206, Step [501/60000], TrainLoss: 1.0497
# Accuracy of the network on the test images: 10.69% & Test Loss: 3.1719681310653685
# Train Log:Epoch: 207, Step [1/60000], TrainLoss: 1.0643
# Train Log:Epoch: 207, Step [501/60000], TrainLoss: 1.0536
# Accuracy of the network on the test images: 10.29% & Test Loss: 3.203294098377228
# Train Log:Epoch: 208, Step [1/60000], TrainLoss: 1.1603
# Train Log:Epoch: 208, Step [501/60000], TrainLoss: 0.9784
# Accuracy of the network on the test images: 10.74% & Test Loss: 3.1938897156715393
# Train Log:Epoch: 209, Step [1/60000], TrainLoss: 1.0230
# Train Log:Epoch: 209, Step [501/60000], TrainLoss: 1.1960
# Accuracy of the network on the test images: 11.29% & Test Loss: 3.182328863143921
# Train Log:Epoch: 210, Step [1/60000], TrainLoss: 1.1568
# Train Log:Epoch: 210, Step [501/60000], TrainLoss: 1.0022
# Accuracy of the network on the test images: 10.82% & Test Loss: 3.2163956713676454
# Train Log:Epoch: 211, Step [1/60000], TrainLoss: 0.9677
# Train Log:Epoch: 211, Step [501/60000], TrainLoss: 1.2725
# Accuracy of the network on the test images: 9.65% & Test Loss: 3.2923730707168577
# Train Log:Epoch: 212, Step [1/60000], TrainLoss: 1.0809
# Train Log:Epoch: 212, Step [501/60000], TrainLoss: 1.1607
# Accuracy of the network on the test images: 10.11% & Test Loss: 3.250411648750305
# Train Log:Epoch: 213, Step [1/60000], TrainLoss: 1.0636
# Train Log:Epoch: 213, Step [501/60000], TrainLoss: 1.1340
# Accuracy of the network on the test images: 10.4% & Test Loss: 3.216710677146912
# Train Log:Epoch: 214, Step [1/60000], TrainLoss: 1.1117
# Train Log:Epoch: 214, Step [501/60000], TrainLoss: 1.0896
# Accuracy of the network on the test images: 10.01% & Test Loss: 3.2858966064453123
# Train Log:Epoch: 215, Step [1/60000], TrainLoss: 0.9213
# Train Log:Epoch: 215, Step [501/60000], TrainLoss: 0.9953
# Accuracy of the network on the test images: 10.44% & Test Loss: 3.2690584373474123
# Train Log:Epoch: 216, Step [1/60000], TrainLoss: 1.1797
# Train Log:Epoch: 216, Step [501/60000], TrainLoss: 1.1576
# Accuracy of the network on the test images: 10.94% & Test Loss: 3.2102442359924317
# Train Log:Epoch: 217, Step [1/60000], TrainLoss: 1.1366
# Train Log:Epoch: 217, Step [501/60000], TrainLoss: 1.2947
# Accuracy of the network on the test images: 9.85% & Test Loss: 3.3005726099014283
# Train Log:Epoch: 218, Step [1/60000], TrainLoss: 1.0241
# Train Log:Epoch: 218, Step [501/60000], TrainLoss: 1.0990
# Accuracy of the network on the test images: 11.23% & Test Loss: 3.2430437183380127
# Train Log:Epoch: 219, Step [1/60000], TrainLoss: 1.1146
# Train Log:Epoch: 219, Step [501/60000], TrainLoss: 0.9789
# Accuracy of the network on the test images: 10.91% & Test Loss: 3.281079800128937
# Train Log:Epoch: 220, Step [1/60000], TrainLoss: 1.1159
# Train Log:Epoch: 220, Step [501/60000], TrainLoss: 1.1176
# Accuracy of the network on the test images: 10.29% & Test Loss: 3.2925503635406494
# Train Log:Epoch: 221, Step [1/60000], TrainLoss: 0.9622
# Train Log:Epoch: 221, Step [501/60000], TrainLoss: 0.9925
# Accuracy of the network on the test images: 10.74% & Test Loss: 3.2780126619338987
# Train Log:Epoch: 222, Step [1/60000], TrainLoss: 1.2133
# Train Log:Epoch: 222, Step [501/60000], TrainLoss: 1.0409
# Accuracy of the network on the test images: 10.1% & Test Loss: 3.306101288795471
# Train Log:Epoch: 223, Step [1/60000], TrainLoss: 0.9545
# Train Log:Epoch: 223, Step [501/60000], TrainLoss: 0.9591
# Accuracy of the network on the test images: 10.46% & Test Loss: 3.2645863270759583
# Train Log:Epoch: 224, Step [1/60000], TrainLoss: 1.0563
# Train Log:Epoch: 224, Step [501/60000], TrainLoss: 1.1077
# Accuracy of the network on the test images: 10.73% & Test Loss: 3.292753190994263
# Train Log:Epoch: 225, Step [1/60000], TrainLoss: 1.0560
# Train Log:Epoch: 225, Step [501/60000], TrainLoss: 1.0386
# Accuracy of the network on the test images: 11.55% & Test Loss: 3.2719756865501406
# Train Log:Epoch: 226, Step [1/60000], TrainLoss: 0.9072
# Train Log:Epoch: 226, Step [501/60000], TrainLoss: 1.0567
# Accuracy of the network on the test images: 10.96% & Test Loss: 3.2961374711990357
# Train Log:Epoch: 227, Step [1/60000], TrainLoss: 1.0526
# Train Log:Epoch: 227, Step [501/60000], TrainLoss: 0.9189
# Accuracy of the network on the test images: 9.82% & Test Loss: 3.3707855629920958
# Train Log:Epoch: 228, Step [1/60000], TrainLoss: 1.0001
# Train Log:Epoch: 228, Step [501/60000], TrainLoss: 1.0127
# Accuracy of the network on the test images: 10.72% & Test Loss: 3.296131944656372
# Train Log:Epoch: 229, Step [1/60000], TrainLoss: 0.9557
# Train Log:Epoch: 229, Step [501/60000], TrainLoss: 1.0433
# Accuracy of the network on the test images: 9.95% & Test Loss: 3.388375563621521
# Train Log:Epoch: 230, Step [1/60000], TrainLoss: 0.8767
# Train Log:Epoch: 230, Step [501/60000], TrainLoss: 1.0545
# Accuracy of the network on the test images: 10.07% & Test Loss: 3.3489143681526183
# Train Log:Epoch: 231, Step [1/60000], TrainLoss: 1.0620
# Train Log:Epoch: 231, Step [501/60000], TrainLoss: 0.9473
# Accuracy of the network on the test images: 10.78% & Test Loss: 3.3709354782104493
# Train Log:Epoch: 232, Step [1/60000], TrainLoss: 1.0196
# Train Log:Epoch: 232, Step [501/60000], TrainLoss: 1.0795
# Accuracy of the network on the test images: 11.39% & Test Loss: 3.2658421921730043
# Train Log:Epoch: 233, Step [1/60000], TrainLoss: 0.9429
# Train Log:Epoch: 233, Step [501/60000], TrainLoss: 0.9564
# Accuracy of the network on the test images: 10.48% & Test Loss: 3.3389705085754393
# Train Log:Epoch: 234, Step [1/60000], TrainLoss: 1.0497
# Train Log:Epoch: 234, Step [501/60000], TrainLoss: 1.1222
# Accuracy of the network on the test images: 11.06% & Test Loss: 3.3801675724983213
# Train Log:Epoch: 235, Step [1/60000], TrainLoss: 1.0519
# Train Log:Epoch: 235, Step [501/60000], TrainLoss: 1.1127
# Accuracy of the network on the test images: 10.89% & Test Loss: 3.367030346393585
# Train Log:Epoch: 236, Step [1/60000], TrainLoss: 1.0126
# Train Log:Epoch: 236, Step [501/60000], TrainLoss: 0.9739
# Accuracy of the network on the test images: 10.28% & Test Loss: 3.388885250091553
# Train Log:Epoch: 237, Step [1/60000], TrainLoss: 1.1804
# Train Log:Epoch: 237, Step [501/60000], TrainLoss: 1.2055
# Accuracy of the network on the test images: 10.68% & Test Loss: 3.368185157775879
# Train Log:Epoch: 238, Step [1/60000], TrainLoss: 0.9218
# Train Log:Epoch: 238, Step [501/60000], TrainLoss: 1.0713
# Accuracy of the network on the test images: 10.06% & Test Loss: 3.417262418270111
# Train Log:Epoch: 239, Step [1/60000], TrainLoss: 0.9585
# Train Log:Epoch: 239, Step [501/60000], TrainLoss: 0.9945
# ...
# Accuracy of the network on the test images: 10.72% & Test Loss: 9.690462093353272
# Train Log:Epoch: 920, Step [1/60000], TrainLoss: 0.0978
# Train Log:Epoch: 920, Step [501/60000], TrainLoss: 0.1031
# Accuracy of the network on the test images: 10.09% & Test Loss: 9.796881198883057
# Train Log:Epoch: 921, Step [1/60000], TrainLoss: 0.0957
# Train Log:Epoch: 921, Step [501/60000], TrainLoss: 0.1298
# Accuracy of the network on the test images: 10.29% & Test Loss: 9.702719020843507
# Train Log:Epoch: 922, Step [1/60000], TrainLoss: 0.0601
# Train Log:Epoch: 922, Step [501/60000], TrainLoss: 0.0794
# Accuracy of the network on the test images: 10.83% & Test Loss: 9.677639918327332
# Train Log:Epoch: 923, Step [1/60000], TrainLoss: 0.1118
# Train Log:Epoch: 923, Step [501/60000], TrainLoss: 0.1145
# Accuracy of the network on the test images: 10.66% & Test Loss: 9.667290153503417
# Train Log:Epoch: 924, Step [1/60000], TrainLoss: 0.1182
# Train Log:Epoch: 924, Step [501/60000], TrainLoss: 0.0906
# Accuracy of the network on the test images: 10.77% & Test Loss: 9.684784383773804
# Train Log:Epoch: 925, Step [1/60000], TrainLoss: 0.0669
# Train Log:Epoch: 925, Step [501/60000], TrainLoss: 0.0541
# Accuracy of the network on the test images: 10.84% & Test Loss: 9.629652094841003
# Train Log:Epoch: 926, Step [1/60000], TrainLoss: 0.1205
# Train Log:Epoch: 926, Step [501/60000], TrainLoss: 0.0885
# Accuracy of the network on the test images: 10.38% & Test Loss: 9.76303569316864
# Train Log:Epoch: 927, Step [1/60000], TrainLoss: 0.0961
# Train Log:Epoch: 927, Step [501/60000], TrainLoss: 0.0829
# Accuracy of the network on the test images: 10.54% & Test Loss: 9.8017311668396
# Train Log:Epoch: 928, Step [1/60000], TrainLoss: 0.0930
# Train Log:Epoch: 928, Step [501/60000], TrainLoss: 0.0925
# Accuracy of the network on the test images: 10.35% & Test Loss: 9.856107869148254
# Train Log:Epoch: 929, Step [1/60000], TrainLoss: 0.0773
# Train Log:Epoch: 929, Step [501/60000], TrainLoss: 0.1038
# Accuracy of the network on the test images: 10.78% & Test Loss: 9.790658020973206
# Train Log:Epoch: 930, Step [1/60000], TrainLoss: 0.0555
# Train Log:Epoch: 930, Step [501/60000], TrainLoss: 0.0963
# Accuracy of the network on the test images: 10.61% & Test Loss: 9.794181709289552
# Train Log:Epoch: 931, Step [1/60000], TrainLoss: 0.0875
# Train Log:Epoch: 931, Step [501/60000], TrainLoss: 0.0729
# Accuracy of the network on the test images: 10.71% & Test Loss: 9.819195532798767
# Train Log:Epoch: 932, Step [1/60000], TrainLoss: 0.0723
# Train Log:Epoch: 932, Step [501/60000], TrainLoss: 0.1068
# Accuracy of the network on the test images: 10.16% & Test Loss: 9.900989017486573
# Train Log:Epoch: 933, Step [1/60000], TrainLoss: 0.1275
# Train Log:Epoch: 933, Step [501/60000], TrainLoss: 0.0504
# Accuracy of the network on the test images: 10.63% & Test Loss: 9.79086518764496
# Train Log:Epoch: 934, Step [1/60000], TrainLoss: 0.0645
# Train Log:Epoch: 934, Step [501/60000], TrainLoss: 0.0892
# Accuracy of the network on the test images: 10.64% & Test Loss: 9.91065106868744
# Train Log:Epoch: 935, Step [1/60000], TrainLoss: 0.1180
# Train Log:Epoch: 935, Step [501/60000], TrainLoss: 0.0919
# Accuracy of the network on the test images: 9.89% & Test Loss: 10.015056095123292
# Train Log:Epoch: 936, Step [1/60000], TrainLoss: 0.0343
# Train Log:Epoch: 936, Step [501/60000], TrainLoss: 0.0561
# Accuracy of the network on the test images: 10.53% & Test Loss: 9.896438355445861
# Train Log:Epoch: 937, Step [1/60000], TrainLoss: 0.0639
# Train Log:Epoch: 937, Step [501/60000], TrainLoss: 0.1024
# Accuracy of the network on the test images: 10.68% & Test Loss: 9.833849945068359
# Train Log:Epoch: 938, Step [1/60000], TrainLoss: 0.0524
# Train Log:Epoch: 938, Step [501/60000], TrainLoss: 0.1134
# Accuracy of the network on the test images: 10.77% & Test Loss: 9.865506577491761
# Train Log:Epoch: 939, Step [1/60000], TrainLoss: 0.1064
# Train Log:Epoch: 939, Step [501/60000], TrainLoss: 0.0620
# Accuracy of the network on the test images: 10.46% & Test Loss: 9.894535422325134
# Train Log:Epoch: 940, Step [1/60000], TrainLoss: 0.0636
# Train Log:Epoch: 940, Step [501/60000], TrainLoss: 0.0997
# Accuracy of the network on the test images: 10.52% & Test Loss: 9.890255479812621
# Train Log:Epoch: 941, Step [1/60000], TrainLoss: 0.0457
# Train Log:Epoch: 941, Step [501/60000], TrainLoss: 0.0985
# Accuracy of the network on the test images: 10.7% & Test Loss: 9.82687475681305
# Train Log:Epoch: 942, Step [1/60000], TrainLoss: 0.0617
# Train Log:Epoch: 942, Step [501/60000], TrainLoss: 0.0648
# Accuracy of the network on the test images: 10.27% & Test Loss: 9.920861129760743
# Train Log:Epoch: 943, Step [1/60000], TrainLoss: 0.0711
# Train Log:Epoch: 943, Step [501/60000], TrainLoss: 0.0650
# Accuracy of the network on the test images: 10.35% & Test Loss: 10.024409551620483
# Train Log:Epoch: 944, Step [1/60000], TrainLoss: 0.1050
# Train Log:Epoch: 944, Step [501/60000], TrainLoss: 0.1168
# Accuracy of the network on the test images: 10.02% & Test Loss: 10.009327940940857
# Train Log:Epoch: 945, Step [1/60000], TrainLoss: 0.0761
# Train Log:Epoch: 945, Step [501/60000], TrainLoss: 0.0790
# Accuracy of the network on the test images: 10.42% & Test Loss: 10.00142252445221
# Train Log:Epoch: 946, Step [1/60000], TrainLoss: 0.1056
# Train Log:Epoch: 946, Step [501/60000], TrainLoss: 0.0582
# Accuracy of the network on the test images: 10.06% & Test Loss: 10.019455900192261
# Train Log:Epoch: 947, Step [1/60000], TrainLoss: 0.0731
# Train Log:Epoch: 947, Step [501/60000], TrainLoss: 0.0467
# Accuracy of the network on the test images: 10.32% & Test Loss: 10.02608793258667
# Train Log:Epoch: 948, Step [1/60000], TrainLoss: 0.0744
# Train Log:Epoch: 948, Step [501/60000], TrainLoss: 0.0553
# Accuracy of the network on the test images: 10.6% & Test Loss: 9.96118950843811
# Train Log:Epoch: 949, Step [1/60000], TrainLoss: 0.0860
# Train Log:Epoch: 949, Step [501/60000], TrainLoss: 0.1322
# Accuracy of the network on the test images: 10.6% & Test Loss: 10.038790001869202
# Train Log:Epoch: 950, Step [1/60000], TrainLoss: 0.1042
# Train Log:Epoch: 950, Step [501/60000], TrainLoss: 0.0442
# Accuracy of the network on the test images: 9.85% & Test Loss: 10.128941311836243
# Train Log:Epoch: 951, Step [1/60000], TrainLoss: 0.1046
# Train Log:Epoch: 951, Step [501/60000], TrainLoss: 0.1005
# Accuracy of the network on the test images: 10.26% & Test Loss: 10.103493580818176
# Train Log:Epoch: 952, Step [1/60000], TrainLoss: 0.1055
# Train Log:Epoch: 952, Step [501/60000], TrainLoss: 0.0462
# Accuracy of the network on the test images: 10.67% & Test Loss: 10.074574494361878
# Train Log:Epoch: 953, Step [1/60000], TrainLoss: 0.0563
# Train Log:Epoch: 953, Step [501/60000], TrainLoss: 0.0898
# Accuracy of the network on the test images: 10.24% & Test Loss: 10.118630290031433
# Train Log:Epoch: 954, Step [1/60000], TrainLoss: 0.0512
# Train Log:Epoch: 954, Step [501/60000], TrainLoss: 0.0574
# Accuracy of the network on the test images: 10.66% & Test Loss: 10.09795114517212
# Train Log:Epoch: 955, Step [1/60000], TrainLoss: 0.0984
# Train Log:Epoch: 955, Step [501/60000], TrainLoss: 0.1005
# Accuracy of the network on the test images: 10.79% & Test Loss: 10.10213493347168
# Train Log:Epoch: 956, Step [1/60000], TrainLoss: 0.0475
# Train Log:Epoch: 956, Step [501/60000], TrainLoss: 0.0928
# Accuracy of the network on the test images: 10.17% & Test Loss: 10.213668932914734
# Train Log:Epoch: 957, Step [1/60000], TrainLoss: 0.0634
# Train Log:Epoch: 957, Step [501/60000], TrainLoss: 0.0946
# Accuracy of the network on the test images: 10.43% & Test Loss: 10.159191040992736
# Train Log:Epoch: 958, Step [1/60000], TrainLoss: 0.0451
# Train Log:Epoch: 958, Step [501/60000], TrainLoss: 0.0772
# Accuracy of the network on the test images: 10.15% & Test Loss: 10.19433907032013
# Train Log:Epoch: 959, Step [1/60000], TrainLoss: 0.1219
# Train Log:Epoch: 959, Step [501/60000], TrainLoss: 0.0890
# Accuracy of the network on the test images: 10.2% & Test Loss: 10.174100737571717
# Train Log:Epoch: 960, Step [1/60000], TrainLoss: 0.1699
# Train Log:Epoch: 960, Step [501/60000], TrainLoss: 0.0972
# Accuracy of the network on the test images: 10.93% & Test Loss: 10.094511828422547
# Train Log:Epoch: 961, Step [1/60000], TrainLoss: 0.1094
# Train Log:Epoch: 961, Step [501/60000], TrainLoss: 0.0685
# Accuracy of the network on the test images: 10.49% & Test Loss: 10.222531533241272
# Train Log:Epoch: 962, Step [1/60000], TrainLoss: 0.0744
# Train Log:Epoch: 962, Step [501/60000], TrainLoss: 0.1082
# Accuracy of the network on the test images: 11.24% & Test Loss: 10.026317420005798
# Train Log:Epoch: 963, Step [1/60000], TrainLoss: 0.0719
# Train Log:Epoch: 963, Step [501/60000], TrainLoss: 0.0943
# Accuracy of the network on the test images: 10.89% & Test Loss: 10.208463621139526
# Train Log:Epoch: 964, Step [1/60000], TrainLoss: 0.0830
# Train Log:Epoch: 964, Step [501/60000], TrainLoss: 0.0620
# Accuracy of the network on the test images: 10.26% & Test Loss: 10.249064574241638
# Train Log:Epoch: 965, Step [1/60000], TrainLoss: 0.0529
# Train Log:Epoch: 965, Step [501/60000], TrainLoss: 0.0764
# Accuracy of the network on the test images: 10.39% & Test Loss: 10.17787474155426
# Train Log:Epoch: 966, Step [1/60000], TrainLoss: 0.0312
# Train Log:Epoch: 966, Step [501/60000], TrainLoss: 0.0778
# Accuracy of the network on the test images: 10.7% & Test Loss: 10.112251605987549
# Train Log:Epoch: 967, Step [1/60000], TrainLoss: 0.0473
# Train Log:Epoch: 967, Step [501/60000], TrainLoss: 0.0852
# Accuracy of the network on the test images: 10.51% & Test Loss: 10.236757969856262
# Train Log:Epoch: 968, Step [1/60000], TrainLoss: 0.0427
# Train Log:Epoch: 968, Step [501/60000], TrainLoss: 0.0629
# Accuracy of the network on the test images: 10.19% & Test Loss: 10.207701663970948
# Train Log:Epoch: 969, Step [1/60000], TrainLoss: 0.0646
# Train Log:Epoch: 969, Step [501/60000], TrainLoss: 0.0367
# Accuracy of the network on the test images: 10.23% & Test Loss: 10.303727211952209
# Train Log:Epoch: 970, Step [1/60000], TrainLoss: 0.0438
# Train Log:Epoch: 970, Step [501/60000], TrainLoss: 0.0691
# Accuracy of the network on the test images: 10.3% & Test Loss: 10.275225892066956
# Train Log:Epoch: 971, Step [1/60000], TrainLoss: 0.0753
# Train Log:Epoch: 971, Step [501/60000], TrainLoss: 0.0921
# Accuracy of the network on the test images: 10.77% & Test Loss: 10.333576545715331
# Train Log:Epoch: 972, Step [1/60000], TrainLoss: 0.0921
# Train Log:Epoch: 972, Step [501/60000], TrainLoss: 0.0926
# Accuracy of the network on the test images: 10.7% & Test Loss: 10.250263705253602
# Train Log:Epoch: 973, Step [1/60000], TrainLoss: 0.0637
# Train Log:Epoch: 973, Step [501/60000], TrainLoss: 0.0589
# Accuracy of the network on the test images: 10.52% & Test Loss: 10.278017182350158
# Train Log:Epoch: 974, Step [1/60000], TrainLoss: 0.0665
# Train Log:Epoch: 974, Step [501/60000], TrainLoss: 0.0613
# Accuracy of the network on the test images: 10.63% & Test Loss: 10.277910423278808
# Train Log:Epoch: 975, Step [1/60000], TrainLoss: 0.0921
# Train Log:Epoch: 975, Step [501/60000], TrainLoss: 0.0950
# Accuracy of the network on the test images: 10.49% & Test Loss: 10.30359067440033
# Train Log:Epoch: 976, Step [1/60000], TrainLoss: 0.0569
# Train Log:Epoch: 976, Step [501/60000], TrainLoss: 0.1048
# Accuracy of the network on the test images: 10.11% & Test Loss: 10.366674060821532
# Train Log:Epoch: 977, Step [1/60000], TrainLoss: 0.0707
# Train Log:Epoch: 977, Step [501/60000], TrainLoss: 0.0940
# Accuracy of the network on the test images: 10.76% & Test Loss: 10.278614501953125
# Train Log:Epoch: 978, Step [1/60000], TrainLoss: 0.0585
# Train Log:Epoch: 978, Step [501/60000], TrainLoss: 0.0482
# Accuracy of the network on the test images: 10.45% & Test Loss: 10.330915303230286
# Train Log:Epoch: 979, Step [1/60000], TrainLoss: 0.0791
# Train Log:Epoch: 979, Step [501/60000], TrainLoss: 0.0949
# Accuracy of the network on the test images: 10.55% & Test Loss: 10.371976885795593
# Train Log:Epoch: 980, Step [1/60000], TrainLoss: 0.0498
# Train Log:Epoch: 980, Step [501/60000], TrainLoss: 0.0611
# Accuracy of the network on the test images: 10.5% & Test Loss: 10.327564792633057
# Train Log:Epoch: 981, Step [1/60000], TrainLoss: 0.0684
# Train Log:Epoch: 981, Step [501/60000], TrainLoss: 0.0650
# Accuracy of the network on the test images: 10.27% & Test Loss: 10.396633710861206
# Train Log:Epoch: 982, Step [1/60000], TrainLoss: 0.0786
# Train Log:Epoch: 982, Step [501/60000], TrainLoss: 0.0856
# Accuracy of the network on the test images: 10.62% & Test Loss: 10.345208325386047
# Train Log:Epoch: 983, Step [1/60000], TrainLoss: 0.0436
# Train Log:Epoch: 983, Step [501/60000], TrainLoss: 0.0529
# Accuracy of the network on the test images: 10.43% & Test Loss: 10.40518268585205
# Train Log:Epoch: 984, Step [1/60000], TrainLoss: 0.0713
# Train Log:Epoch: 984, Step [501/60000], TrainLoss: 0.0848
# Accuracy of the network on the test images: 10.04% & Test Loss: 10.442964968681336
# Train Log:Epoch: 985, Step [1/60000], TrainLoss: 0.0758
# Train Log:Epoch: 985, Step [501/60000], TrainLoss: 0.1072
# Accuracy of the network on the test images: 9.99% & Test Loss: 10.464958124160766
# Train Log:Epoch: 986, Step [1/60000], TrainLoss: 0.0398
# Train Log:Epoch: 986, Step [501/60000], TrainLoss: 0.0538
# Accuracy of the network on the test images: 10.42% & Test Loss: 10.463956718444825
# Train Log:Epoch: 987, Step [1/60000], TrainLoss: 0.0536
# Train Log:Epoch: 987, Step [501/60000], TrainLoss: 0.0717
# Accuracy of the network on the test images: 9.89% & Test Loss: 10.573973050117493
# Train Log:Epoch: 988, Step [1/60000], TrainLoss: 0.0780
# Train Log:Epoch: 988, Step [501/60000], TrainLoss: 0.0331
# Accuracy of the network on the test images: 9.97% & Test Loss: 10.541685438156128
# Train Log:Epoch: 989, Step [1/60000], TrainLoss: 0.0806
# Train Log:Epoch: 989, Step [501/60000], TrainLoss: 0.0642
# Accuracy of the network on the test images: 10.67% & Test Loss: 10.41693645954132
# Train Log:Epoch: 990, Step [1/60000], TrainLoss: 0.1093
# Train Log:Epoch: 990, Step [501/60000], TrainLoss: 0.1231
# Accuracy of the network on the test images: 10.48% & Test Loss: 10.46759578704834
# Train Log:Epoch: 991, Step [1/60000], TrainLoss: 0.0901
# Train Log:Epoch: 991, Step [501/60000], TrainLoss: 0.0562
# Accuracy of the network on the test images: 10.3% & Test Loss: 10.486342234611511
# Train Log:Epoch: 992, Step [1/60000], TrainLoss: 0.0302
# Train Log:Epoch: 992, Step [501/60000], TrainLoss: 0.0874
# Accuracy of the network on the test images: 10.65% & Test Loss: 10.569670085906983
# Train Log:Epoch: 993, Step [1/60000], TrainLoss: 0.0393
# Train Log:Epoch: 993, Step [501/60000], TrainLoss: 0.0641
# Accuracy of the network on the test images: 10.13% & Test Loss: 10.592243080139161
# Train Log:Epoch: 994, Step [1/60000], TrainLoss: 0.0791
# Train Log:Epoch: 994, Step [501/60000], TrainLoss: 0.0878
# Accuracy of the network on the test images: 10.94% & Test Loss: 10.457104530334473
# Train Log:Epoch: 995, Step [1/60000], TrainLoss: 0.0709
# Train Log:Epoch: 995, Step [501/60000], TrainLoss: 0.0489
# Accuracy of the network on the test images: 10.15% & Test Loss: 10.570481071472168
# Train Log:Epoch: 996, Step [1/60000], TrainLoss: 0.0659
# Train Log:Epoch: 996, Step [501/60000], TrainLoss: 0.0720
# Accuracy of the network on the test images: 10.24% & Test Loss: 10.570327067375183
# Train Log:Epoch: 997, Step [1/60000], TrainLoss: 0.0410
# Train Log:Epoch: 997, Step [501/60000], TrainLoss: 0.0842
# Accuracy of the network on the test images: 10.05% & Test Loss: 10.609470639228821
# Train Log:Epoch: 998, Step [1/60000], TrainLoss: 0.0875
# Train Log:Epoch: 998, Step [501/60000], TrainLoss: 0.0831
# Accuracy of the network on the test images: 10.54% & Test Loss: 10.51707615852356
# Train Log:Epoch: 999, Step [1/60000], TrainLoss: 0.0555
# Train Log:Epoch: 999, Step [501/60000], TrainLoss: 0.0770
# Accuracy of the network on the test images: 10.02% & Test Loss: 10.654040689468383
# Train Log:Epoch: 1000, Step [1/60000], TrainLoss: 0.0598
# Train Log:Epoch: 1000, Step [501/60000], TrainLoss: 0.0565
# Accuracy of the network on the test images: 10.66% & Test Loss: 10.529756512641907

# %%
#Plotting Train Vs Test Loss
plt.plot(epochArr,train_loss_arr,color="Blue")
plt.plot(epochArr,test_loss_arr,color="red")
plt.legend(['Train Loss','Test Loss'],loc="upper right")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("random labels train vs test loss",color = "green")

plt.show()
